# %%
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import pandas as pd
import os
import sklearn.metrics
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)

# %%
# Load the .npy files from the parent directory
X_train = np.load('./Our_Saved/X_train.npy')
y_train = np.load('./Our_Saved/y_train.npy')

X_test = np.load('./Our_Saved/X_test.npy')
y_test = np.load('./Our_Saved/y_test.npy')

print(f"X_train: {X_train.shape}")
print(f"X_test: {X_test.shape}")
print(f"y_train: {y_train.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# X_train: (18, 500, 3)
# X_test: (6, 500, 3)
# y_train: (18,)
# y_test: (6,)

# %% [markdown]
# # Using Raw Accelerometer Data

# %% [markdown]
# ## Approach-1: Reshaping X_train from shape (126,500,3) to (126,1500)

# %% [markdown]
# ### SkLearn's Decision Tree

# %%
X_train_stacked=np.hstack((X_train[:,:,0],X_train[:,:,1],X_train[:,:,2]))
X_test_stacked=np.hstack((X_test[:,:,0],X_test[:,:,1],X_test[:,:,2]))

print(f"X_train_stacked: {X_train_stacked.shape}")
print(f"y_train: {y_train.shape}")
print(f"x_test: {X_test_stacked.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# X_train_stacked: (18, 1500)
# y_train: (18,)
# x_test: (6, 1500)
# y_test: (6,)

# %%
dt1=DecisionTreeClassifier(random_state=42)
dt1.fit(X_train_stacked,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_dt1=dt1.predict(X_test_stacked)

# %%
print("Accuracy: ",sklearn.metrics.accuracy_score(y_test, y_pred_dt1))
print("Precision: ",sklearn.metrics.precision_score(y_test, y_pred_dt1,average='macro'))
print("Recall: ",sklearn.metrics.recall_score(y_test, y_pred_dt1,average='macro'))
# Out:
# Accuracy:  0.5
# Precision:  0.4166666666666667
# Recall:  0.5
# c:\Users\Shardul Junagade\Desktop\es335-24-fall-assignment-1\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### My Decision Tree Implementation

# %%
import sys
import os

# Add the path to the directory containing tree.py
sys.path.append(os.path.abspath("../"))

from tree.base import DecisionTree
# Train the model
model = DecisionTree(criterion='information_gain', max_depth=10)
model.fit(pd.DataFrame(X_train_stacked), pd.Series(y_train))
print("fitted")
# Predict the test set
y_pred = model.predict(pd.DataFrame(X_test_stacked))

# Calculate the accuracy
print("Accuracy: ",sklearn.metrics.accuracy_score(y_test, y_pred))
print("Precision: ",sklearn.metrics.precision_score(y_test, y_pred,average='macro'))
print("Recall: ",sklearn.metrics.recall_score(y_test, y_pred,average='macro'))
# Out:
# DecisionTree(criterion=information_gain, max_depth=10)
#
# Tree Structure:
# Tree not trained yet
# fitted
# DecisionTree(criterion=information_gain, max_depth=10)
#
# Tree Structure:
# ?(attr 692 <= -0.18)
#     Yes: ?(attr 8 <= 0.78)
#         Yes: Class: 1
#         No: ?(attr 0 <= 0.89)
#             Yes: Class: 3
#             No: Class: 2
#     No: ?(attr 0 <= 1.02)
#         Yes: ?(attr 0 <= 0.14)
#             Yes: Class: 6
#             No: Class: 4
#         No: ?(attr 0 <= 1.03)
#             Yes: Class: 5
#             No: Class: 3
#
# Accuracy:  0.5
# Precision:  0.4166666666666667
# Recall:  0.5
# c:\Users\Shardul Junagade\Desktop\es335-24-fall-assignment-1\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Approach-2: Using Linear acceleration from X_train

# %% [markdown]
# ### SkLearn's Decision Tree

# %%
linear_acc_train = X_train[:,:,0]**2 + X_train[:,:,1]**2 + X_train[:,:,2]**2
linear_acc_test = X_test[:,:,0]**2 + X_test[:,:,1]**2 + X_test[:,:,2]**2

print(f"linear_acc_train: {linear_acc_train.shape}")
print(f"y_train: {y_train.shape}")
print(f"linear_acc_test: {linear_acc_test.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# linear_acc_train: (18, 500)
# y_train: (18,)
# linear_acc_test: (6, 500)
# y_test: (6,)

# %%
dt=DecisionTreeClassifier(random_state=42)
dt.fit(linear_acc_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_linear=dt.predict(linear_acc_test)

# %%
print("Accuracy: ",sklearn.metrics.accuracy_score(y_test, y_pred_linear))
print("Precision: ",sklearn.metrics.precision_score(y_test, y_pred_linear,average='macro'))
print("Recall: ",sklearn.metrics.recall_score(y_test, y_pred_linear,average='macro'))
# Out:
# Accuracy:  0.6666666666666666
# Precision:  0.5833333333333334
# Recall:  0.6666666666666666
# c:\Users\Shardul Junagade\Desktop\es335-24-fall-assignment-1\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### My Decision Tree Implementation

# %%
import sys
import os

# Add the path to the directory containing tree.py
sys.path.append(os.path.abspath("../"))

from tree.base import DecisionTree
# Train the model
model = DecisionTree(criterion='information_gain', max_depth=10)
model.fit(pd.DataFrame(linear_acc_train), pd.Series(y_train))
print("fitted")
print(model)
# Predict the test set
y_pred = model.predict(pd.DataFrame(linear_acc_test))

# Calculate the accuracy
print("Accuracy: ",sklearn.metrics.accuracy_score(y_test, y_pred))
print("Precision: ",sklearn.metrics.precision_score(y_test, y_pred,average='macro'))
print("Recall: ",sklearn.metrics.recall_score(y_test, y_pred,average='macro'))
# Out:
# fitted
# DecisionTree(criterion=information_gain, max_depth=10)
#
# Tree Structure:
# ?(attr 57 <= 0.92)
#     Yes: ?(attr 29 <= 1.03)
#         Yes: ?(attr 2 <= 1.14)
#             Yes: Class: 3
#             No: Class: 2
#         No: Class: 1
#     No: ?(attr 1 <= 1.02)
#         Yes: ?(attr 7 <= 1.01)
#             Yes: Class: 6
#             No: Class: 3
#         No: ?(attr 6 <= 1.05)
#             Yes: Class: 4
#             No: Class: 5
#
# Accuracy:  0.5
# Precision:  0.3333333333333333
# Recall:  0.5
# c:\Users\Shardul Junagade\Desktop\es335-24-fall-assignment-1\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# # Using TSFEL features

# %%
import tsfel
# Extract features using TSFEL
cfg = tsfel.get_features_by_domain()  # Get all features by default
X_train_tsfel = tsfel.time_series_features_extractor(cfg, X_train, verbose=1,fs =50)
X_test_tsfel = tsfel.time_series_features_extractor(cfg, X_test, verbose=1,fs =50)

print(f"X_train_tsfel: {X_train_tsfel.shape}")
print(f"X_test_tsfel: {X_test_tsfel.shape}")
print(f"y_train: {y_train.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='18'
#                   max='18',
#                   style='width: 25%',
#               >
#                   18
#               </progress>
# *** Feature extraction finished ***
# *** Feature extraction started ***
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='6'
#                   max='6',
#                   style='width: 25%',
#               >
#                   6
#               </progress>
# *** Feature extraction finished ***
# X_train_tsfel: (18, 1152)
# X_test_tsfel: (6, 1152)
# y_train: (18,)
# y_test: (6,)

# %%
dt2=DecisionTreeClassifier(random_state=42)
dt2.fit(X_train_tsfel,y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_tsfel_pred=dt2.predict(X_test_tsfel)

# %%
print("Accuracy: ",sklearn.metrics.accuracy_score(y_test, y_tsfel_pred))
print("Precision: ",sklearn.metrics.precision_score(y_test, y_tsfel_pred,average='macro'))
print("Recall: ",sklearn.metrics.recall_score(y_test, y_tsfel_pred,average='macro'))
# Out:
# Accuracy:  0.5
# Precision:  0.4166666666666667
# Recall:  0.5
# c:\Users\Shardul Junagade\Desktop\es335-24-fall-assignment-1\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Using decision tree fitted on features obtained after standardizing and applying PCA to the TSFEL data

# %%
from sklearn.feature_selection import VarianceThreshold

# Highly correlated features are removed
corr_features = tsfel.correlated_features(X_train_tsfel, threshold=0.95)
X_train_tsfel.drop(corr_features, axis=1, inplace=True)
X_test_tsfel.drop(corr_features, axis=1, inplace=True)
print("Shape of train data after removing correlated features:",X_train_tsfel.shape)
print("Shape of test data after removing correlated features:",X_test_tsfel.shape)

# Remove low variance features
selector = VarianceThreshold(threshold = 0.1) # default is 0
X_train_tsfel = selector.fit_transform(X_train_tsfel)
X_test_tsfel = selector.transform(X_test_tsfel)
print("\nShape of train data after removing low variance features:",X_train_tsfel.shape)
print("Shape of test data after removing low variance features:",X_test_tsfel.shape)
# Out:
# Shape of train data after removing correlated features: (18, 519)
# Shape of test data after removing correlated features: (6, 519)
#
# Shape of train data after removing low variance features: (18, 100)
# Shape of test data after removing low variance features: (6, 100)

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Normalising Features
scaler = StandardScaler()
X_train_tsfel_scaled = scaler.fit_transform(X_train_tsfel)
X_test_tsfel_scaled = scaler.transform(X_test_tsfel)

# Applying PCA
tsfel_pca = PCA(n_components=5)
X_train_tsfel_pca = tsfel_pca.fit_transform(X_train_tsfel_scaled)
X_test_tsfel_pca = tsfel_pca.transform(X_test_tsfel_scaled)

print("Training data shape after PCA: ",X_train_tsfel_pca.shape)
print("Testing data shape after PCA: ",X_test_tsfel_pca.shape)
# Out:
# Training data shape after PCA:  (18, 5)
# Testing data shape after PCA:  (6, 5)

# %%
dt3=DecisionTreeClassifier(random_state=42)
dt3.fit(X_train_tsfel_pca,y_train)

y_tsfel_pca_pred=dt3.predict(X_test_tsfel_pca)

print("Accuracy: ",sklearn.metrics.accuracy_score(y_test, y_tsfel_pca_pred))
print("Precision: ",sklearn.metrics.precision_score(y_test, y_tsfel_pca_pred,average='macro'))
print("Recall: ",sklearn.metrics.recall_score(y_test, y_tsfel_pca_pred,average='macro'))
# Out:
# Accuracy:  0.6666666666666666
# Precision:  0.5555555555555555
# Recall:  0.6666666666666666
# c:\Users\Shardul Junagade\Desktop\es335-24-fall-assignment-1\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
